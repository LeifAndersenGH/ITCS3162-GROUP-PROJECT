# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
# %matplotlib inline

# %%
labelencoder = preprocessing.LabelEncoder()

# %%
df = pd.read_csv("ford.csv")

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.isnull().any()
# Out:
# model           False
# year            False
# price           False
# transmission    False
# mileage         False
# fuelType        False
# tax             False
# mpg             False
# engineSize      False
# dtype: bool

# %%
obj_df = df.select_dtypes(include=['object']).copy()

# %%
obj_df.head()
# Out:
#      model transmission fuelType
# 0   Fiesta    Automatic   Petrol
# 1    Focus       Manual   Petrol
# 2    Focus       Manual   Petrol
# 3   Fiesta       Manual   Petrol
# 4   Fiesta    Automatic   Petrol

# %%
obj_df['model'].value_counts()
# Out:
#  Fiesta                   6557
#  Focus                    4588
#  Kuga                     2225
#  EcoSport                 1143
#  C-MAX                     543
#  Ka+                       531
#  Mondeo                    526
#  B-MAX                     355
#  S-MAX                     296
#  Grand C-MAX               247
#  Galaxy                    228
#  Edge                      208
#  KA                        199
#  Puma                       80
#  Tourneo Custom             69
#  Grand Tourneo Connect      59
#  Mustang                    57
#  Tourneo Connect            33
#  Fusion                     16
#  Streetka                    2
#  Ranger                      1
#  Escort                      1
#  Transit Tourneo             1
# Name: model, dtype: int64

# %%
obj_df['transmission'].value_counts()
# Out:
# Manual       15517
# Automatic     1361
# Semi-Auto     1087
# Name: transmission, dtype: int64

# %%
obj_df['fuelType'].value_counts()
# Out:
# Petrol      12178
# Diesel       5762
# Hybrid         22
# Electric        2
# Other           1
# Name: fuelType, dtype: int64

# %%
# encode model_enc col
obj_df['model_enc'] = labelencoder.fit_transform(df['model'])

# %%
# encode transmission_enc col
obj_df['transmission_enc'] = labelencoder.fit_transform(df['transmission'])

# %%
# encode fuelType col
obj_df['fuelType_enc'] = labelencoder.fit_transform(df['fuelType'])

# %%
obj_df.columns
# Out:
# Index(['model', 'transmission', 'fuelType', 'model_enc', 'transmission_enc',
#        'fuelType_enc'],
#       dtype='object')

# %%
### MODEL CODES

#  B-MAX                        0
#  C-MAX                        1
#  EcoSport                     2
#  Edge                         3
#  Escort                       4
#  Fiesta                       5
#  Focus                        6
#  Fusion                       7
#  Galaxy                       8
#  Grand C-MAX                  9
#  Grand Tourneo Connect        10
#  KA                           11
#  Ka+                          12
#  Kuga                         13
#  Mondeo                       14
#  Mustang                      15
#  Puma                         16
#  Ranger                       17
#  S-MAX                        18
#  Streetka                     19
#  Tourneo Connect              20
#  Tourneo Custom               21
#  Transit Tourneo              22


### TRANSMISSION CODES
#  Automatic                     0
#  Manual                        1
#  Semi-Auto                     2


### FUEL TYPE CODE

#  Diesel                        0
#  Electric                      1
#  Hydbrid                       2
#  Other                         3
#  Petrol                        4

# %%
df.loc[df['price'] > 50000]
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 11912   Focus  2018  54995       Manual    11000   Petrol  145  36.7
#
#        engineSize
# 11912         2.3

# %%
df.loc[df['mpg'] >= 100]
# Out:
#        model  year  price transmission  mileage fuelType  tax    mpg  \
# 6153    Kuga  2020  31000    Semi-Auto       10   Hybrid  135  201.8
# 6536    Kuga  2020  31991    Semi-Auto     2357   Hybrid  135  201.8
# 9220    Kuga  2020  32000    Automatic       10   Hybrid  140  201.8
# 12862   Kuga  2020  33500    Automatic     5534   Hybrid  140  201.8
# 13730   Kuga  2020  32995    Automatic       11   Hybrid  135  201.8
#
#        engineSize
# 6153          2.5
# 6536          2.5
# 9220          2.5
# 12862         2.5
# 13730         2.5

# %%
df['model'] = labelencoder.fit_transform(df['model'])

# %%
df['transmission'] = labelencoder.fit_transform(df['transmission'])

# %%
df['fuelType'] = labelencoder.fit_transform(df['fuelType'])

# %%
# locate car from the year 2060
df.loc[df['year'] >= 2025]
# Out:
#        model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 17726      5  2060   6495             0    54807         4  205  42.8
#
#        engineSize
# 17726         1.4

# %%
# Drop the 2060 ford fiesta
df = df.drop(17726)

# %%
# Make sure deleted fiesta
df.loc[df['year'] >= 2025]
# Out:
# Empty DataFrame
# Columns: [model, year, price, transmission, mileage, fuelType, tax, mpg, engineSize]
# Index: []

# %%
df.loc[df['mpg'] > 100]
# Out:
#        model  year  price  transmission  mileage  fuelType  tax    mpg  \
# 6153      13  2020  31000             2       10         2  135  201.8
# 6536      13  2020  31991             2     2357         2  135  201.8
# 9220      13  2020  32000             0       10         2  140  201.8
# 12862     13  2020  33500             0     5534         2  140  201.8
# 13730     13  2020  32995             0       11         2  135  201.8
#
#        engineSize
# 6153          2.5
# 6536          2.5
# 9220          2.5
# 12862         2.5
# 13730         2.5

# %%
df.loc[df['mpg'] < 75]
# Out:
#        model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 0          5  2017  12000             0    15944         4  150  57.7
# 1          6  2018  14000             1     9083         4  150  57.7
# 2          6  2017  13000             1    12456         4  150  57.7
# 3          5  2019  17500             1    10460         4  145  40.3
# 4          5  2019  16500             0     1482         4  145  48.7
# ...      ...   ...    ...           ...      ...       ...  ...   ...
# 17960      5  2016   7999             1    31348         4  125  54.3
# 17961      0  2017   8999             1    16700         4  150  47.1
# 17962      0  2014   7499             1    40700         4   30  57.7
# 17963      6  2015   9999             1     7010         0   20  67.3
# 17964     11  2018   8299             1     5007         4  145  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# 17960         1.2
# 17961         1.4
# 17962         1.0
# 17963         1.6
# 17964         1.2
#
# [17483 rows x 9 columns]

# %%
df = df.drop(df[df['mpg'] > 50].index)

# %%
df.loc[df['mpg'] > 50]
# Out:
# Empty DataFrame
# Columns: [model, year, price, transmission, mileage, fuelType, tax, mpg, engineSize]
# Index: []

# %%
df.loc[df['mpg'] <28]
# Out:
#        model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 302       15  2020  42489             0     3500         4  145  22.1
# 354       15  2018  31498             0     6250         4  145  23.5
# 364       15  2016  24999             2    42086         4  570  23.5
# 387       15  2019  39998             0     5000         4  145  22.6
# 741       15  2018  29998             1    20847         4  145  20.9
# 2264      15  2020  39990             2      691         4  145  22.1
# 3163      15  2017  27890             2    26452         4  580  23.5
# 3395      15  2017  28000             2    23179         4  570  23.5
# 3469      15  2017  31317             2     9511         4  145  23.5
# 3496      15  2018  33000             2     5064         4  145  23.5
# 3687      15  2016  26475             1    12000         4  570  20.9
# 5015      15  2020  37990             0     2450         4  145  22.1
# 5342      15  2019  37991             0     1055         4  145  22.1
# 5351      15  2018  30927             0     9268         4  145  23.5
# 5523      15  2020  37990             2      151         4  145  22.1
# 6136      15  2016  27999             2    26104         4  570  20.8
# 7164      15  2020  40495             2     3200         4  145  24.8
# 7182      15  2017  32990             0    12000         4  145  20.8
# 8354      15  2018  31991             2    28915         4  145  22.1
# 9462      15  2019  38000             2     1780         4  145  22.1
# 9695      15  2019  41000             2      678         4  145  22.1
# 9790      15  2016  28490             0    18500         4  570  23.5
# 10373     15  2018  28615             1    17876         4  145  20.9
# 10670     15  2019  40000             1      813         4  145  22.8
# 10736     15  2019  40495             0     2000         4  145  22.1
# 10901     15  2020  42999             1       10         4  145  23.7
# 11097     15  2016  27925             1    11600         4  580  20.9
# 11205     15  2019  36799             2    10810         4  145  22.1
# 11910     15  2017  48999             0     7546         4  145  23.5
# 11913     15  2017  49999             1    21575         4  145  20.9
# 12400     15  2017  28000             2     8470         4  570  23.5
# 12600     15  2020  41000             1      100         4  145  22.8
# 12613     15  2019  45250             0     2500         4  145  22.1
# 12996     15  2019  42500             0      226         4  145  22.1
# 13041     15  2017  27990             1    17030         4  150  20.9
# 13356     15  2018  37500             1     5572         4  145  20.8
# 13418     15  2017  27500             1    20700         4  150  20.9
# 13425     15  2018  32000             0     5000         4  145  23.5
# 13431     15  2019  42000             2      756         4  150  22.6
# 13532     15  2017  29980             0    24000         4  150  23.5
# 13741     13  2012   9490             0    56384         4  555  27.4
# 14910     13  2012   8150             0    69382         4  555  27.4
# 15729     15  2018  28489             1    15744         4  150  20.9
# 16713      6  2007   5995             1    67000         4  330  26.3
# 16842      6  2007   6995             1    68000         4  325  26.3
# 17207     15  2018  30500             1     5000         4  145  20.9
# 17304     15  2019  39995             0      800         4  145  22.1
# 17866     15  2020  48000             1       50         4  145  23.9
#
#        engineSize
# 302           5.0
# 354           5.0
# 364           5.0
# 387           5.0
# 741           5.0
# 2264          5.0
# 3163          5.0
# 3395          5.0
# 3469          5.0
# 3496          5.0
# 3687          5.0
# 5015          5.0
# 5342          5.0
# 5351          5.0
# 5523          5.0
# 6136          5.0
# 7164          5.0
# 7182          5.0
# 8354          5.0
# 9462          5.0
# 9695          5.0
# 9790          5.0
# 10373         5.0
# 10670         5.0
# 10736         5.0
# 10901         5.0
# 11097         5.0
# 11205         5.0
# 11910         5.0
# 11913         5.0
# 12400         5.0
# 12600         5.0
# 12613         5.0
# 12996         5.0
# 13041         5.0
# 13356         5.0
# 13418         5.0
# 13425         5.0
# 13431         5.0
# 13532         5.0
# 13741         2.5
# 14910         2.5
# 15729         5.0
# 16713         2.5
# 16842         2.5
# 17207         5.0
# 17304         5.0
# 17866         5.0

# %%
sns.jointplot(x='mpg', y='price', data=df, hue='year')

# %%
sns.jointplot(x='year', y='price', data=df, hue='engineSize')

# %%
# predictor var
X = df[['year', 'mpg', 'engineSize', 'fuelType']]

# prediction var
y = df['price']

x_train, x_test, y_train, y_test = train_test_split(X, y)

# %%
# run sklearn, fit the linear model 
lr = linear_model.LinearRegression() 
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# accuracy of guesses
lr.score(X, y)
# Out:
# 0.7578088831979379

# %%
y_pred = lr.predict(x_test)

# %%
lr_diff = pd.DataFrame({'Actual Value':y_test, 'Predicted Value':y_pred})

# %%
lr_diff.head(50)
# Out:
#        Actual Value  Predicted Value
# 2160           5490     10012.782360
# 16254         11000     14719.260877
# 12385         19500     20245.062872
# 9007          17500     23315.840654
# 4749          19998     18547.843275
# 6206          29999     23632.415683
# 16542         13699     19503.778736
# 16977          5795      5870.983843
# 15699         10495     12898.029356
# 3624          13140     14087.619522
# 11652          8595     11260.586543
# 5970          16000     13439.511752
# 16713          5995      8630.683153
# 3043          18991     17052.989442
# 16794          5495      4401.577140
# 8909          10699     13218.017359
# 4836          14998     15227.451819
# 13330         32000     20498.322895
# 17373          2645      4736.648103
# 11880         14250     12601.567092
# 11079         12800     16096.999917
# 11398         21999     21650.278560
# 8041          19000     18166.265226
# 13123          9000     14421.002470
# 5066          17400     18166.265226
# 1223          17530     15793.640522
# 4887          18000     18166.265226
# 10034         17500     18199.610743
# 7998          12387     13218.017359
# 4786          16995     18199.610743
# 15560         12000     11891.940459
# 16406          3875      2345.760840
# 11207         11880     14704.069789
# 11954         15999     15925.604897
# 13525         21780     23474.128169
# 1801          17998     17039.827873
# 6274          17990     18547.843275
# 14515          1795      3845.082968
# 4539          15920     13439.511752
# 15235         11999     13218.017359
# 15163         12000     13582.949682
# 2200          20645     15836.842762
# 11703         18499     18199.610743
# 3958           8700     10279.203953
# 7974          28995     25880.098390
# 1800          16998     16818.225353
# 4             16500     13724.429278
# 17524         15000     15583.582739
# 10202          9390     11260.586543
# 11822         16099     13724.429278

# %%
df['predicted_price'] = lr_diff['Predicted Value']

# %%
df = df[df['predicted_price'].notna()]

# %%
df.head(50)
# Out:
#       model  year  price  transmission  mileage  fuelType  tax   mpg  \
# 4         5  2019  16500             0     1482         4  145  48.7
# 5         5  2015  10500             1    35432         4  145  47.9
# 75       13  2017  17920             0    15815         4  235  38.2
# 111      13  2019  19495             1    13673         0  145  47.9
# 125      13  2019  19995             1    11312         0  145  47.9
# 156      13  2019  20495             1    12034         0  145  47.9
# 173      13  2017  16995             0     3700         4  145  38.2
# 183       6  2017  17998             1     9066         4  145  41.5
# 187       6  2017  14998             1    32511         4  150  41.5
# 201       6  2017  17998             1    19525         4  145  41.5
# 231       2  2017   9298             1    16770         4  145  44.8
# 236       6  2017  15500             1    19593         4  145  41.5
# 251      13  2019  23998             1     7584         0  145  39.2
# 293       1  2019  13498             1    23394         4  145  48.7
# 297       5  2019  11798             1     4590         4  150  48.7
# 353      15  2018  29998             0     3000         4  145  28.8
# 357       6  2019  16998             0     8703         4  145  40.9
# 376       3  2017  23899             0    27146         0  145  47.9
# 402       0  2013   5998             2    44582         4  165  44.1
# 420      13  2019  18494             1    11858         0  145  38.2
# 459      13  2013   9998             2    43938         0  205  45.6
# 471       5  2016   8449             1    79125         4  145  47.9
# 482       3  2017  20994             0    41000         0  145  48.7
# 527      12  2019   9950             1      906         4  145  43.5
# 542      13  2019  19998             0     8757         4  145  28.8
# 549       5  2019  11698             1     3578         4  150  48.7
# 577       6  2019  15998             1    10386         4  145  49.6
# 605       2  2017  10798             2     3652         4  165  44.8
# 620       2  2015   8000             1    29681         4  160  44.8
# 629       6  2017  18998             1    10222         4  145  41.5
# 649       5  2013   7998             2    22125         4  150  47.9
# 675      13  2013  10998             1    32347         0  200  47.9
# 741      15  2018  29998             1    20847         4  145  20.9
# 763      13  2019  19498             1     9420         4  145  39.2
# 782       0  2013   6498             2    33155         4  160  44.1
# 796       6  2017  16798             1    18215         4  145  41.5
# 818       6  2019  25498             1     4813         4  145  34.5
# 841       6  2017  17630             1    25526         4  145  41.5
# 864       1  2015   7798             1    35901         4  160  44.1
# 895       2  2017   9498             1    15750         4  145  44.8
# 992       6  2017  14000             1    43000         4  150  41.5
# 1027      0  2014   7998             2    29044         4  165  44.1
# 1064     12  2019  10600             1     2179         4  145  47.9
# 1107      6  2017  18491             1    18523         4  200  41.5
# 1125      6  2017  16495             1    33770         4  145  41.5
# 1132      5  2013   7860             2    23079         4  145  47.9
# 1137      6  2018  19700             1     8022         4  145  41.5
# 1147     12  2018   9291             1     4191         4  145  47.9
# 1160      2  2018  14790             2    14487         4  145  48.7
# 1173      2  2017   9550             1    21791         4  145  44.8
#
#       engineSize  predicted_price
# 4            1.0     13724.429278
# 5            1.6     10279.203953
# 75           1.5     15925.604897
# 111          2.0     20245.062872
# 125          2.0     20245.062872
# 156          2.0     20245.062872
# 173          1.5     15925.604897
# 183          2.0     16696.858522
# 187          2.0     16696.858522
# 201          2.0     16696.858522
# 231          1.5     13836.209705
# 236          2.0     16696.858522
# 251          2.0     22999.265625
# 293          1.0     13724.429278
# 297          1.1     14087.619522
# 353          2.3     23276.338827
# 357          1.5     18009.665725
# 376          2.0     17306.249466
# 402          1.6      8543.375657
# 420          2.0     23315.840654
# 459          2.0     12156.745220
# 471          1.6     11748.610656
# 482          2.0     17052.989442
# 527          1.2     16096.999917
# 542          1.5     21840.223577
# 549          1.1     14087.619522
# 577          1.0     13439.511752
# 605          1.5     13836.209705
# 620          1.5     10897.396299
# 629          2.0     16696.858522
# 649          1.6      7340.390546
# 675          2.0     11428.622653
# 741          5.0     35583.418150
# 763          1.5     18547.843275
# 782          1.6      8543.375657
# 796          2.0     16696.858522
# 818          2.3     22941.267865
# 841          2.0     16696.858522
# 864          1.6     11482.189064
# 895          1.5     13836.209705
# 992          2.0     16696.858522
# 1027         1.6     10012.782360
# 1064         1.2     14704.069789
# 1107         2.0     16696.858522
# 1125         2.0     16696.858522
# 1132         1.6      7340.390546
# 1137         2.0     18166.265226
# 1147         1.2     13234.663086
# 1160         1.0     12255.022574
# 1173         1.5     13836.209705

# %%
indexNames = df[df['predicted_price'] < 200 ].index
df.drop(indexNames , inplace=True)

# %%
sns.jointplot(x='predicted_price', y='price', data=df, hue='price')

# %%
sns.lmplot(
    data = df, 
    x = "price",
    y = "predicted_price",
    order = 2
)

# %%
sns.regplot(x="predicted_price", y="price", data=df);

# %%
sns.lmplot(x="predicted_price", y="price", data=df, x_estimator=np.mean);

# %%
sns.lmplot(x="predicted_price", y="mpg", hue="engine_size", data=df);
