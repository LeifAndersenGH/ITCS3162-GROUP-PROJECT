# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import preprocessing
# %matplotlib inline

# %%
labelencoder = preprocessing.LabelEncoder()

# %%
df = pd.read_csv("ford.csv")

# %%
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.isnull().any()
# Out:
# model           False
# year            False
# price           False
# transmission    False
# mileage         False
# fuelType        False
# tax             False
# mpg             False
# engineSize      False
# dtype: bool

# %%
# no nulls
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [model, year, price, transmission, mileage, fuelType, tax, mpg, engineSize]
# Index: []

# %%
obj_df = df.select_dtypes(include=['object']).copy()

# %%
obj_df.head()
# Out:
#      model transmission fuelType
# 0   Fiesta    Automatic   Petrol
# 1    Focus       Manual   Petrol
# 2    Focus       Manual   Petrol
# 3   Fiesta       Manual   Petrol
# 4   Fiesta    Automatic   Petrol

# %%
obj_df['model'].value_counts()
# Out:
#  Fiesta                   6557
#  Focus                    4588
#  Kuga                     2225
#  EcoSport                 1143
#  C-MAX                     543
#  Ka+                       531
#  Mondeo                    526
#  B-MAX                     355
#  S-MAX                     296
#  Grand C-MAX               247
#  Galaxy                    228
#  Edge                      208
#  KA                        199
#  Puma                       80
#  Tourneo Custom             69
#  Grand Tourneo Connect      59
#  Mustang                    57
#  Tourneo Connect            33
#  Fusion                     16
#  Streetka                    2
#  Ranger                      1
#  Escort                      1
#  Transit Tourneo             1
# Name: model, dtype: int64

# %%
obj_df['transmission'].value_counts()
# Out:
# Manual       15517
# Automatic     1361
# Semi-Auto     1087
# Name: transmission, dtype: int64

# %%
obj_df['fuelType'].value_counts()
# Out:
# Petrol      12178
# Diesel       5762
# Hybrid         22
# Electric        2
# Other           1
# Name: fuelType, dtype: int64

# %%
# encode model_enc col
obj_df['model_enc'] = labelencoder.fit_transform(df['model'])

# %%
# encode transmission_enc col
obj_df['transmission_enc'] = labelencoder.fit_transform(df['transmission'])

# %%
# encode fuelType col
obj_df['fuelType_enc'] = labelencoder.fit_transform(df['fuelType'])

# %%
list(map(set,obj_df.values))
# Out:
# [{' Fiesta', 0, 4, 5, 'Automatic', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 4, 5, 'Automatic', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Puma', 1, 16, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 'Automatic', 'Diesel'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Mondeo', 0, 1, 14, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Tourneo Custom', 0, 21, 'Automatic', 'Diesel'},
#  {' S-MAX', 0, 18, 'Automatic', 'Diesel'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 'Automatic', 'Diesel'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' B-MAX', 0, 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' S-MAX', 0, 1, 18, 'Diesel', 'Manual'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 4, 'Automatic', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Edge', 0, 1, 3, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Tourneo Connect', 0, 1, 20, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 13, 4, 'Automatic', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Tourneo Connect', 1, 20, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 2, 4, 6, 'Petrol', 'Semi-Auto'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Tourneo Connect', 0, 1, 20, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Puma', 1, 16, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 2, 'Diesel', 'Semi-Auto'},
#  {' Tourneo Custom', 0, 1, 21, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Mondeo', 0, 1, 14, 'Diesel', 'Manual'},
#  {' Grand C-MAX', 1, 4, 9, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Tourneo Connect', 0, 1, 20, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 2, 6, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' B-MAX', 0, 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Mondeo', 0, 1, 14, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' EcoSport', 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 4, 'Automatic', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' B-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 4, 6, 'Automatic', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 0, 4, 5, 'Automatic', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 4, 'Automatic', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' B-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' KA', 1, 11, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Focus', 2, 4, 6, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' S-MAX', 0, 18, 2, 'Diesel', 'Semi-Auto'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 2, 4, 6, 'Petrol', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' C-MAX', 0, 1, 2, 'Diesel', 'Semi-Auto'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 4, 6, 'Automatic', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' B-MAX', 0, 1, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 1, 4, 9, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Galaxy', 0, 1, 8, 'Diesel', 'Manual'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 2, 4, 6, 'Petrol', 'Semi-Auto'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Galaxy', 0, 2, 8, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Mustang', 0, 15, 4, 'Automatic', 'Petrol'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Grand Tourneo Connect', 0, 1, 10, 'Diesel', 'Manual'},
#  {' Kuga', 0, 13, 'Automatic', 'Diesel'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Mondeo', 0, 14, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Mondeo', 0, 14, 2, 'Automatic', 'Hybrid'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Edge', 0, 3, 'Automatic', 'Diesel'},
#  {' Mustang', 0, 15, 4, 'Automatic', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Mustang', 0, 15, 4, 'Automatic', 'Petrol'},
#  {' Mustang', 0, 15, 4, 'Automatic', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Grand Tourneo Connect', 0, 10, 'Automatic', 'Diesel'},
#  {' Focus', 0, 4, 6, 'Automatic', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' S-MAX', 0, 1, 18, 'Diesel', 'Manual'},
#  {' S-MAX', 0, 1, 18, 'Diesel', 'Manual'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Mustang', 15, 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Edge', 0, 1, 3, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Grand Tourneo Connect', 0, 1, 10, 'Diesel', 'Manual'},
#  {' B-MAX', 0, 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Focus', 0, 4, 6, 'Automatic', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Edge', 0, 3, 'Automatic', 'Diesel'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 4, 'Automatic', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Mustang', 0, 15, 4, 'Automatic', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' B-MAX', 0, 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Mondeo', 0, 1, 14, 'Diesel', 'Manual'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' B-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Galaxy', 0, 1, 8, 'Diesel', 'Manual'},
#  {' B-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' B-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' S-MAX', 0, 1, 18, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Edge', 0, 3, 'Automatic', 'Diesel'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' S-MAX', 0, 1, 18, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Mondeo', 0, 1, 14, 'Diesel', 'Manual'},
#  {' Tourneo Custom', 0, 1, 21, 'Diesel', 'Manual'},
#  {' Tourneo Custom', 0, 1, 21, 'Diesel', 'Manual'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Grand Tourneo Connect', 0, 1, 10, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' B-MAX', 0, 1, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' B-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Kuga', 0, 13, 4, 'Automatic', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' S-MAX', 0, 1, 18, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Grand Tourneo Connect', 0, 10, 'Automatic', 'Diesel'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 2, 6, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 2, 4, 6, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' KA', 1, 11, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' B-MAX', 0, 1, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Tourneo Connect', 0, 1, 20, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' EcoSport', 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Mondeo', 0, 14, 2, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 4, 5, 'Automatic', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' B-MAX', 0, 1, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' KA', 1, 11, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Edge', 0, 1, 3, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 4, 6, 'Automatic', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Fiesta', 0, 4, 5, 'Automatic', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' B-MAX', 0, 1, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 1, 4, 9, 'Manual', 'Petrol'},
#  {' Focus', 2, 4, 6, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Mondeo', 0, 14, 2, 'Diesel', 'Semi-Auto'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' KA', 1, 11, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Mustang', 1, 15, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Grand Tourneo Connect', 0, 10, 'Automatic', 'Diesel'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Mondeo', 0, 1, 14, 'Diesel', 'Manual'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Mondeo', 0, 14, 2, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' B-MAX', 0, 2, 4, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 2, 4, 6, 'Petrol', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 4, 6, 'Automatic', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' S-MAX', 0, 1, 18, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' C-MAX', 0, 1, 'Diesel', 'Manual'},
#  {' Focus', 0, 2, 6, 'Diesel', 'Semi-Auto'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 0, 1, 2, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 13, 2, 'Diesel', 'Semi-Auto'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' C-MAX', 1, 4, 'Manual', 'Petrol'},
#  {' Mondeo', 0, 1, 14, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Grand C-MAX', 0, 1, 9, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Mondeo', 0, 14, 2, 'Diesel', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Puma', 1, 16, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' B-MAX', 0, 1, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 4, 6, 'Automatic', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Fiesta', 2, 4, 5, 'Petrol', 'Semi-Auto'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Ka+', 1, 12, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 1, 13, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 4, 6, 'Automatic', 'Petrol'},
#  {' Focus', 0, 6, 'Automatic', 'Diesel'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' EcoSport', 1, 2, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' Kuga', 0, 1, 13, 'Diesel', 'Manual'},
#  {' B-MAX', 0, 1, 4, 'Manual', 'Petrol'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 0, 1, 5, 'Diesel', 'Manual'},
#  {' KA', 1, 11, 4, 'Manual', 'Petrol'},
#  {' Focus', 0, 1, 6, 'Diesel', 'Manual'},
#  {' Focus', 1, 4, 6, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  {' Fiesta', 1, 4, 5, 'Manual', 'Petrol'},
#  ...]

# %%
### MODEL CODES

#  B-MAX                        0
#  C-MAX                        1
#  EcoSport                     2
#  Edge                         3
#  Escort                       4
# Fiesta                        5
#  Focus                        6
#  Fusion                       7
#  Galaxy                       8
#  Grand C-MAX                  9
#  Grand Tourneo Connect        10
#  KA                           11
#  Ka+                          12
#  Kuga                         13
#  Mondeo                       14
#  Mustang                      15
#  Puma                         16
#  Ranger                       17
#  S-MAX                        18
#  Streetka                     19
#  Tourneo Connect              20
#  Tourneo Custom               21
#  Transit Tourneo              22


### TRANSMISSION CODES
#  Automatic                     0
#  Manual                        1
#  Semi-Auto                     2


### FUEL TYPE CODE

#  Diesel                        0
#  Electric                      1
#  Hydbrid                       2
#  Other                         3
#  Petrol                        4

# %%
df['model'] = labelencoder.fit_transform(df['model'])

# %%
df['transmission'] = labelencoder.fit_transform(df['transmission'])

# %%
df['fuelType'] = labelencoder.fit_transform(df['fuelType'])

# %%
sns.heatmap(df.corr(), annot=True)

# %%
sns.lmplot(x='mpg', y='mileage', data=df,
           fit_reg=False, # No regression line
           hue='engineSize')   # Color by evolution stage

# %%
sns.scatterplot(x="price", y="year", data = df)

# %%
sns.scatterplot(x="price", y="mileage", data = df)

# %%
sns.barplot(x="engineSize", y="price", data = df)

# %%
sns.barplot(x="mpg", y="price", data = df)

# %%
sns.scatterplot(x="mpg", y="price", data = df)
